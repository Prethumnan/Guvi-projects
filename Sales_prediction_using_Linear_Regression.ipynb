# %% [markdown]
# <a href="https://colab.research.google.com/github/Prethumnan/guvi-project/blob/main/Sales_prediction_using_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import plotly.express as px

# %%
data=pd.read_csv("train.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0              FDA15        9.300  ...  Supermarket Type1          3735.1380
# 1              DRC01        5.920  ...  Supermarket Type2           443.4228
# 2              FDN15       17.500  ...  Supermarket Type1          2097.2700
# 3              FDX07       19.200  ...      Grocery Store           732.3800
# 4              NCD19        8.930  ...  Supermarket Type1           994.7052
# ...              ...          ...  ...                ...                ...
# 8518           FDF22        6.865  ...  Supermarket Type1          2778.3834
# 8519           FDS36        8.380  ...  Supermarket Type1           549.2850
# 8520           NCJ29       10.600  ...  Supermarket Type1          1193.1136
# 8521           FDN46        7.210  ...  Supermarket Type2          1845.5976
# 8522           DRG01       14.800  ...  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
data["Item_Fat_Content"].replace({"LF":"Low Fat","reg":"Regular","low fat":"Low Fat"},inplace=True)

# %%
#Filling Nan values with mean
data["Item_Weight"].fillna(data["Item_Weight"].mean(),inplace=True)

# %%
data["Outlet_Size"].fillna(0,inplace=True)

# %%
#Filling Nan values with mode
data["Outlet_Size"].replace({0:"Medium"},inplace=True)

# %%
data["Outlet_Size"].value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
n=[]
for i in range(len(data)):
    n.append(data["Item_Identifier"][i][0:2])
new=pd.DataFrame({"Item_Type_Combined":n})
new
df=pd.concat([new,data],axis=1)

# %%
df["Item_Type_Combined"].replace({"FD":"Food","DR":"Drinks","NC":"Non-Consumable"},inplace=True)

# %%
#If Item_Type_Combined is non-consumable then we are replacing item_fat_content as non-edible
df.loc[df["Item_Type_Combined"]=="Non-Consumable","Item_Fat_Content"]="Non-Edible"
df["Item_Fat_Content"].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
#since this data is taken at the year of 2013
df["Outlet_Year"]=2013-df["Outlet_Establishment_Year"]

# %%
df
# Out:
#      Item_Type_Combined Item_Identifier  ...  Item_Outlet_Sales Outlet_Year
# 0                  Food           FDA15  ...          3735.1380          14
# 1                Drinks           DRC01  ...           443.4228           4
# 2                  Food           FDN15  ...          2097.2700          14
# 3                  Food           FDX07  ...           732.3800          15
# 4        Non-Consumable           NCD19  ...           994.7052          26
# ...                 ...             ...  ...                ...         ...
# 8518               Food           FDF22  ...          2778.3834          26
# 8519               Food           FDS36  ...           549.2850          11
# 8520     Non-Consumable           NCJ29  ...          1193.1136           9
# 8521               Food           FDN46  ...          1845.5976           4
# 8522             Drinks           DRG01  ...           765.6700          16
#
# [8523 rows x 14 columns]

# %%
#univariant analysis
sns.distplot(df["Item_Weight"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(df["Item_Visibility"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(df["Item_MRP"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(df["Item_Outlet_Sales"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
#since the outlet sales is right skewed,we are doing Log transformation
df["Item_Outlet_Sales"]=np.log(1+df["Item_Outlet_Sales"])

# %%
sns.distplot(df["Item_Outlet_Sales"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.countplot(df["Item_Fat_Content"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(df["Outlet_Size"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(df["Outlet_Location_Type"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df["Outlet_Type"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(24,6))
sns.countplot(df["Item_Type"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(df["Outlet_Establishment_Year"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f8a74d78-dae1-4736-ab52-5f079bf5e4ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f8a74d78-dae1-4736-ab52-5f079bf5e4ea")) {
#                     Plotly.newPlot(
#                         'f8a74d78-dae1-4736-ab52-5f079bf5e4ea',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Outlet_Identifier=%{x}<br>Item_Outlet_Sales=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "line": {"width": 0}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["OUT049", "OUT018", "OUT049", "OUT010", "OUT013", "OUT018", "OUT013", "OUT027", "OUT045", "OUT017", "OUT049", "OUT046", "OUT049", "OUT046", "OUT013", "OUT046", "OUT018", "OUT049", "OUT027", "OUT035", "OUT013", "OUT027", "OUT035", "OUT019", "OUT046", "OUT017", "OUT035", "OUT013", "OUT010", "OUT019", "OUT010", "OUT018", "OUT018", "OUT045", "OUT046", "OUT049", "OUT027", "OUT018", "OUT027", "OUT027", "OUT046", "OUT013", "OUT049", "OUT018", "OUT013", "OUT010", "OUT045", "OUT045", "OUT046", "OUT019", "OUT046", "OUT013", "OUT013", "OUT017", "OUT017", "OUT018", "OUT045", "OUT049", "OUT046", "OUT019", "OUT018", "OUT045", "OUT027", "OUT019", "OUT027", "OUT010", "OUT035", "OUT045", "OUT045", "OUT046", "OUT046", "OUT013", "OUT045", "OUT017", "OUT049", "OUT046", "OUT049", "OUT019", "OUT017", "OUT045", "OUT046", "OUT046", "OUT018", "OUT019", "OUT027", "OUT017", "OUT035", "OUT027", "OUT046", "OUT049", "OUT010", "OUT049", "OUT045", "OUT035", "OUT035", "OUT019", "OUT049", "OUT035", "OUT027", "OUT046", "OUT045", "OUT027", "OUT049", "OUT013", "OUT018", "OUT013", "OUT013", "OUT045", "OUT019", "OUT013", "OUT046", "OUT017", "OUT019", "OUT027", "OUT045", "OUT049", "OUT017", "OUT035", "OUT017", "OUT018", "OUT017", "OUT045", "OUT010", "OUT035", "OUT017", "OUT035", "OUT046", "OUT017", "OUT013", "OUT045", "OUT027", "OUT046", "OUT027", "OUT010", "OUT018", "OUT046", "OUT027", "OUT045", "OUT017", "OUT010", "OUT035", "OUT017", "OUT045", "OUT049", "OUT035", "OUT049", "OUT035", "OUT035", "OUT035", "OUT035", "OUT017", "OUT018", "OUT018", "OUT027", "OUT046", "OUT018", "OUT018", "OUT017", "OUT017", "OUT013", "OUT013", "OUT027", "OUT018", "OUT046", "OUT046", "OUT017", "OUT017", "OUT018", "OUT027", "OUT018", "OUT035", "OUT017", "OUT013", "OUT013", "OUT010", "OUT010", "OUT045", "OUT010", "OUT019", "OUT045", "OUT027", "OUT045", "OUT019", "OUT013", "OUT027", "OUT018", "OUT019", "OUT049", "OUT045", "OUT049", "OUT049", "OUT049", "OUT045", "OUT018", "OUT027", "OUT046", "OUT046", "OUT049", "OUT027", "OUT027", "OUT045", "OUT035", "OUT045", "OUT027", "OUT046", "OUT010", "OUT049", "OUT045", "OUT019", "OUT010", "OUT035", "OUT035", "OUT017", "OUT045", "OUT010", "OUT010", "OUT010", "OUT010", "OUT013", "OUT035", "OUT049", "OUT017", "OUT046", "OUT017", "OUT013", "OUT019", "OUT013", "OUT019", "OUT035", "OUT027", "OUT027", "OUT027", "OUT045", "OUT035", "OUT046", "OUT027", "OUT019", "OUT013", "OUT027", "OUT027", "OUT045", "OUT017", "OUT035", "
"Small", "Medium", "Medium", "Medium", "Medium", "Small", "Medium", "Small", "High", "Medium", "Small", "High", "High", "Small", "Medium", "Medium", "Medium", "Medium", "Small", "Small", " ...

# %%
Outlet_Location_Type = px.bar(df, x="Outlet_Location_Type", y="Item_Outlet_Sales")
Outlet_Location_Type.update_traces(dict(marker_line_width=0))
Outlet_Location_Type.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f071c769-0718-4587-8474-035919b5ef14" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f071c769-0718-4587-8474-035919b5ef14")) {
#                     Plotly.newPlot(
#                         'f071c769-0718-4587-8474-035919b5ef14',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Outlet_Location_Type=%{x}<br>Item_Outlet_Sales=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "line": {"width": 0}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 1", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 2", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 1", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 1", "Tier 1", "Tier 1", "Tier 3", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 3", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 1", "Tier 1", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 1", "Tier 1", "Tier 3", "Tier 1", "Tier 2", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 2", "Tier 3", "Tier 1", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 3", "Tier 1", "Tier 2", "Tier 1", "Tier 3", "Tier 2", "Tier 1", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 1", "Tier 2", "Tier 3", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 1", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 1", "Tier 2", "Tier 1", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 1", "Tier 1", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 1", "Tier 2", "Tier 3", "Tier 2", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 1", "Tier 1", "Tier 2", "Tier 1", "Tier 1", "Tier 1", "Tier 2", "Tier 3", "Tier 3", "Tier 1", "Tier 1", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 1", "Tier 2", "Tier 1", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 2", "Tier 1", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 1", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 1", "Tier 2", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 2", "Tier 1", "Tier 2", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 2", "Tier 1", "Tier 2", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 2", "Tier 3", "Tier 2", "Tier 3", "Tier 3", "Tier 1", "Tier 2", "Tier 1", "Tier 2", "Tier 1", "Tier 3", "Tier 1", "Tier 2", "Tier 3", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 1", "Tier 2", "Tier 2", "Tier 1", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 2", "Tier 3", "Tier 2", "Tier 3", "Tier 3", "Tier 1", "Tier 2", "Tier 2", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 2", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 1", "Tier 3", "Tier 1", "Tier 2", "Tier 2", "Tier 2", "Tier 3", "Tier 3", "Tier 3", "Tier 2", "Tier 1", "Tier 1", "Tier 1", "Tier 1", "Tier 1", "Tier 3", "Tier 3", "Tier 2", "Tier 3", "Tier 1", "Tier 1", "Tier 1", "Tier 1", "Tier 3", "Tier 1", "Tier 3", "Tier 3", "Tier 1", "Tier 2", "Tier 1", "Tier 1", "Ti ...

# %%
Outlet_Type = px.bar(df, x="Outlet_Type", y="Item_Outlet_Sales")
Outlet_Type.update_traces(dict(marker_line_width=0))
Outlet_Type.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ca17c881-e354-467e-a815-541f7563fb90" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca17c881-e354-467e-a815-541f7563fb90")) {
#                     Plotly.newPlot(
#                         'ca17c881-e354-467e-a815-541f7563fb90',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Outlet_Type=%{x}<br>Item_Outlet_Sales=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "line": {"width": 0}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Grocery Store", "Grocery Store", "Supermarket Type2", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type2", "Supermarket Type3", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type2", "Supermarket Type1", "Supermarket Type3", "Grocery Store", "Supermarket Type3", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Grocery Store", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type3", "Grocery Store", "Supermarket Type2", "Supermarket Type1", "Supermarket Type3", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type2", "Supermarket Type3", "Supermarket Type1", "Supermarket Type2", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type3", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type2", "Supermarket Type3", "Supermarket Type2", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Supermarket Type1", "Grocery Store", "Grocery Store", "Supermarket Type1", "Grocery Store", "Grocery Sto ...

# %%
Outlet_Establishment_Year = px.bar(df, x="Outlet_Establishment_Year", y="Item_Outlet_Sales")
Outlet_Establishment_Year.update_traces(dict(marker_line_width=0))
Outlet_Establishment_Year.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a1c75d49-ebac-42be-9084-2d1d50a21f1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a
, 1998, 1985, 1997, 1997, 2002, 1997, 1985, 2002, 1999, 1999, 1997, 2009, 2002, 1985, 2002, 2004, 1997, 1985, 1985, 1999, 1997, 1987, 1985, 1997, 1998, 2009, 1997, 1997, 2007, 2004, 1985, 2002, 2007, 1998, 2002, 1999, 2009, 1999, 1999, 2009, 2009, 2002, 2002, 1985, 1997, 1999, 1985, 1985, 1987, 1997, 2002, 1999, 1987, 1997, 1997, 2002, 1999, 2009, 2004, 1985, 1987, 2007, 1985, 2004, 1997, 2009, 2002, 1987, 2004, 1985, 1997, 1985, 1987, 1987, 2007, 1997, 2007, 2009, 2004, 1987, 2007, 2002, 2009, 2002, 2002, 1985, 1999, 1997, 1997, 2004, 1998, 2002, 2002, 1987, 2004, 1997, 1998, 2004, 1985, 2002, 1985, 1997, 1985, 1985, 1985, 2007, 1998, 2004, 1999, 1987, 1985, 2004, 2002, 2007, 1999, 1998, 2007, 1985, 2009, 2009, 2007, 2004, 1985, 1998, 2002, 2009, 2002, 1987, 2002, 2002, 2009, 1985, 1985, 1987, 1998, 1998, 1987, 2002, 1997, 2009, 1985, 2007, 2002, 1987, 1998, 1998, 1999, 2007, 1997, 2004, 1985, 1997, 2004, 1998, 2007, 1985, 1987, 2004, 1985, 1999, 1998, 2002, 1999, 2004, 1997, 1985, 1997, 2007, 2007, 1985, 1985, 2007, 2002, 2009, 1998, 1999, 1985, 2004, 1987, 2002, 1999, 1999, 2002, 2007, 2009, 2002, 2009, 1985, 2009, 1997, 2004, 1987, 1999, 1999, 2007, 2009, 2002, 1997, 2004, 2002, 1987, 1985, 1997, 2002, 2007, 2004, 1987, 1997, 2002, 2009, 2007, 1985, 1997, 1997, 1997, 2009, 1999, 1997, 2004, 2002, 2004,  ...

# %%
#Let's check the correlation between the numerical values
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")

# %%
#Doing label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Outlet"]=le.fit_transform(df["Outlet_Identifier"])
cat_colms=["Item_Fat_Content","Item_Type","Outlet_Size","Outlet_Location_Type","Outlet_Type","Item_Type_Combined"]
for c in cat_colms:
    df[c]=le.fit_transform(df[c])

# %%
#Deleting the columns which are already processed
new=df.drop(["Outlet_Identifier","Outlet_Establishment_Year","Item_Identifier"],axis=1)
new
# Out:
#       Item_Type_Combined  Item_Weight  ...  Outlet_Year  Outlet
# 0                      1        9.300  ...           14       9
# 1                      0        5.920  ...            4       3
# 2                      1       17.500  ...           14       9
# 3                      1       19.200  ...           15       0
# 4                      2        8.930  ...           26       1
# ...                  ...          ...  ...          ...     ...
# 8518                   1        6.865  ...           26       1
# 8519                   1        8.380  ...           11       7
# 8520                   2       10.600  ...            9       6
# 8521                   1        7.210  ...            4       3
# 8522                   0       14.800  ...           16       8
#
# [8523 rows x 12 columns]

# %%
#Doing one hot encoding
new=pd.get_dummies(new,columns=["Item_Fat_Content","Outlet_Size","Outlet_Location_Type","Outlet_Type","Item_Type_Combined"])

# %%
new.shape
# Out:
# (8523, 23)

# %%
#Defining variables
x=new.drop("Item_Outlet_Sales",axis=1)
y=new["Item_Outlet_Sales"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#Traing the model
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Checkin cross validation score
y_pred=model.predict(x_test)
cross_val_score(model,x,y)
# Out:
# array([0.72131137, 0.71070495, 0.70749188, 0.71531541, 0.74011399])

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.3085943540937238
