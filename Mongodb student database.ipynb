# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = pymongo.MongoClient("mongodb+srv://prethumnan:Karuna99@cluster0.7a8wk.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %%
data=client.get_database("STUDENTS")
fol=data.exam

# %%
for i in fol.find():
    print(i)
    break
# Out:
# {'_id': 0, 'name': 'aimee Zank', 'scores': [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}]}

# %%
name=[]
new=[]
for i in fol.find():
    name.append(i["name"])
for i in fol.find():
    j=i["scores"]
    for k in j:
        new.append([k["score"],k["type"]])

# %%
for i in fol.find():
    j=i["scores"]
    for k in j:
        print(k)
    break
# Out:
# {'score': 1.463179736705023, 'type': 'exam'}
# {'score': 11.78273309957772, 'type': 'quiz'}
# {'score': 35.8740349954354, 'type': 'homework'}

# %%
exam=[]
quiz=[]
homework=[]
for i,j in new:
    if j=="exam":
        exam.append(i)
    elif j=="quiz":
        quiz.append(i)
    else:
        homework.append(i)

# %%
data=pd.DataFrame({"name":name,"exam":exam,"quiz":quiz,"homework":homework})

# %%
data
# Out:
#                  name       exam       quiz   homework
# 0          aimee Zank   1.463180  11.782733  35.874035
# 1    Aurelia Menendez  60.060451  52.797907  71.761334
# 2         Corliss Zuk  67.030771   6.301852  66.283447
# 3          Bao Ziglar  71.643439  24.802213  42.261471
# 4    Zachary Langlais  78.683851  90.296310  34.416201
# ..                ...        ...        ...        ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084
# 196  Santiago Dollins  52.040526  33.633001  78.792574
# 197     Tonisha Games  38.512696  31.162876  79.158564
# 198    Timothy Harrod  11.907567  20.518800  64.856504
# 199        Rae Kohout  82.117426  49.612955  28.868237
#
# [200 rows x 4 columns]

# %%
#1) Find the student name who scored maximum scores in all (exam, quiz and homework)?

# %%
data["total"]=data["exam"]+data["quiz"]+data["homework"]

# %%
topers=data.sort_values("total",ascending=False)
print("students who scored maximum in all")
l=[i for i in topers["name"][0:3]]
o=1
for i in l:
    print(o,i)
    o+=1
# Out:
# students who scored maximum in all
# 1 Jessika Dagenais
# 2 Whitley Fears
# 3 Tawana Oberg

# %%
data.columns[1:-1]
# Out:
# Index(['exam', 'quiz', 'homework'], dtype='object')

# %%
import numpy as np
for i in data.columns[1:-1]:
    data["{0}_Result".format(i)]=np.where(data[i]>=40,"Pass","Fail")

# %%
data
# Out:
#                  name       exam       quiz   homework       total  \
# 0          aimee Zank   1.463180  11.782733  35.874035   49.119948
# 1    Aurelia Menendez  60.060451  52.797907  71.761334  184.619692
# 2         Corliss Zuk  67.030771   6.301852  66.283447  139.616069
# 3          Bao Ziglar  71.643439  24.802213  42.261471  138.707123
# 4    Zachary Langlais  78.683851  90.296310  34.416201  203.396363
# ..                ...        ...        ...        ...         ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084  154.973373
# 196  Santiago Dollins  52.040526  33.633001  78.792574  164.466100
# 197     Tonisha Games  38.512696  31.162876  79.158564  148.834135
# 198    Timothy Harrod  11.907567  20.518800  64.856504   97.282871
# 199        Rae Kohout  82.117426  49.612955  28.868237  160.598617
#
#     exam_Result quiz_Result homework_Result
# 0          Fail        Fail            Fail
# 1          Pass        Pass            Pass
# ...

# %%
#2) Find students who scored below average in the exam and pass mark is 40%?

# %%
m=[]
for i in range(len(data)):
    m.append([data["name"][i],data["exam"][i]])
l=[]
for i,j in m:
    if j>=40 and j<=50:
        l.append([i,j])
k=[]
u=[]
for i,j in l:
    k.append(i)
    u.append(j)
below_average=pd.DataFrame({"name":k,"exam_marks":u})
below_average.sort_values("exam_marks",ascending=False)
# Out:
#                 name  exam_marks
# 23       Kam Senters   49.882254
# 13  Mercedez Garduno   49.528770
# 6    Gwyneth Garling   48.366450
# 24    Mariela Sherer   47.671967
# 12  Demarcus Audette   47.426086
# 4       Rosana Vales   46.228948
# 5   Tamika Schildgen   45.654328
# 1       Denisha Cast   45.618769
# 0     Wilburn Spiess   44.871863
# 7       Kayce Kenyon   44.624417
# 2       Gisela Levin   44.512111
# 18   Gwyneth Garling   44.295535
# 16     Alix Sherrill   43.674362
# 11        Cassi Heal   43.043110
# 19     Aleida Elsass   42.895583
# 17  Laureen Salomone   42.543230
# 3     Tressa Schwing   42.174398
# 8     Terica Brugger   42.101131
# 22  Harriett Velarde   41.479883
# 20      Alica Pasley   41.385282
# 9          Chad Rahe   40.845720
# 21     Malisa Jeanes   40.686760
# 14       Flora Duell   40.682390
# 15    Quincy Danaher   40.531369
# 10   Jenise Mcguffie   40.152105

# %%
#3)Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.

# %%
data
# Out:
#                  name       exam       quiz   homework       total  \
# 0          aimee Zank   1.463180  11.782733  35.874035   49.119948
# 1    Aurelia Menendez  60.060451  52.797907  71.761334  184.619692
# 2         Corliss Zuk  67.030771   6.301852  66.283447  139.616069
# 3          Bao Ziglar  71.643439  24.802213  42.261471  138.707123
# 4    Zachary Langlais  78.683851  90.296310  34.416201  203.396363
# ..                ...        ...        ...        ...         ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084  154.973373
# 196  Santiago Dollins  52.040526  33.633001  78.792574  164.466100
# 197     Tonisha Games  38.512696  31.162876  79.158564  148.834135
# 198    Timothy Harrod  11.907567  20.518800  64.856504   97.282871
# 199        Rae Kohout  82.117426  49.612955  28.868237  160.598617
#
#     exam_Result quiz_Result homework_Result total_Result
# 0          Fail        Fail            Fail         Pass
# ...

# %%
#4)Find the total and average of the exam, quiz and homework and store them in a separate collection.

# %%
data["Average"]=(data["exam"]+data["quiz"]+data["homework"])/3

# %%
data
# Out:
#                  name       exam       quiz   homework       total  \
# 0          aimee Zank   1.463180  11.782733  35.874035   49.119948
# 1    Aurelia Menendez  60.060451  52.797907  71.761334  184.619692
# 2         Corliss Zuk  67.030771   6.301852  66.283447  139.616069
# 3          Bao Ziglar  71.643439  24.802213  42.261471  138.707123
# 4    Zachary Langlais  78.683851  90.296310  34.416201  203.396363
# ..                ...        ...        ...        ...         ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084  154.973373
# 196  Santiago Dollins  52.040526  33.633001  78.792574  164.466100
# 197     Tonisha Games  38.512696  31.162876  79.158564  148.834135
# 198    Timothy Harrod  11.907567  20.518800  64.856504   97.282871
# 199        Rae Kohout  82.117426  49.612955  28.868237  160.598617
#
#     exam_Result quiz_Result homework_Result total_Result    Average
# 0          Fail        Fail            Fail         Pass  16.373316
# ...

# %%
average_and_total=data[["total","Average"]]
average_and_total
# Out:
#           total    Average
# 0     49.119948  16.373316
# 1    184.619692  61.539897
# 2    139.616069  46.538690
# 3    138.707123  46.235708
# 4    203.396363  67.798788
# ..          ...        ...
# 195  154.973373  51.657791
# 196  164.466100  54.822033
# 197  148.834135  49.611378
# 198   97.282871  32.427624
# 199  160.598617  53.532872
#
# [200 rows x 2 columns]

# %%
#5)Create a new collection which consists of students who scored below average and above 40% in all the categories.

# %%
m=[]
for i in range(len(data)):
    m.append([data["name"][i],data["exam"][i],data["quiz"][i],data["homework"][i]])
l=[]
for a,b,c,d in m:
    if ((b>=40 and b<=50) and (c>=40 and c<=50)) and (d>=40 and d<=50):
        l.append([a,b,c,d])

q=[]
w=[]
e=[]
r=[]
for a,b,c,d in l:
    q.append(a)
    w.append(b)
    e.append(c)
    r.append(d)
all_cat_below_avg=pd.DataFrame({"name":q,"exam":w,"quiz":e,"homework":r})
print("There are no persons who scored below average and above 40% in all categories")
# Out:
# There are no persons who scored below average and above 40% in all categories

# %%
#6)Create a new collection which consists of students who scored below the fail mark in all the categories.

# %%
m=[]
for i in range(len(data)):
    m.append([data["name"][i],data["exam"][i],data["quiz"][i],data["homework"][i]])
l=[]
for a,b,c,d in m:
    if ((b<40) and (c<40)) and (d<40):
        l.append([a,b,c,d])

q=[]
w=[]
e=[]
r=[]
for a,b,c,d in l:
    q.append(a)
    w.append(b)
    e.append(c)
    r.append(d)
fail_mark=pd.DataFrame({"name":q,"exam":w,"quiz":e,"homework":r})
fail_mark
# Out:
#          name     exam       quiz   homework
# 0  aimee Zank  1.46318  11.782733  35.874035

# %%
#7)Create a new collection which consists of students who scored above pass mark in all the categories.

# %%
m=[]
for i in range(len(data)):
    m.append([data["name"][i],data["exam"][i],data["quiz"][i],data["homework"][i]])
l=[]
for a,b,c,d in m:
    if ((b>=40) and (c>=40)) and (d>=40):
        l.append([a,b,c,d])

q=[]
w=[]
e=[]
r=[]
for a,b,c,d in l:
    q.append(a)
    w.append(b)
    e.append(c)
    r.append(d)
pass_mark=pd.DataFrame({"name":q,"exam":w,"quiz":e,"homework":r})
pass_mark
# Out:
#                  name       exam       quiz   homework
# 0    Aurelia Menendez  60.060451  52.797907  71.761334
# 1        Salena Olmos  90.378265  42.487807  96.529862
# 2        Denisha Cast  45.618769  98.357232  55.908357
# 3        Marcus Blohm  78.426178  82.583728  87.499247
# 4      Quincy Danaher  54.298413  85.612702  80.407324
# 5    Jessika Dagenais  90.471800  90.300140  95.177538
# 6    Verdell Sowinski  62.128702  84.745862  81.589478
# 7      Tressa Schwing  42.174398  71.993148  81.239726
# 8    Tamika Schildgen  45.654328  64.329270  83.539334
# 9          Gwen Honig  87.143454  99.458244  76.664605
# 10   Eugene Magdaleno  73.055900  79.856216  66.091437
# 11       Tawana Oberg  80.590061  93.284381  93.121340
# 12        Joel Rueter  87.536369  92.709747  61.790326
# 13        Tresa Sinha  94.931370  72.322261  77.248769
# 14        Grady Zemke  51.915613  50.083494  95.341393
# 15      Whitley Fears  89.618458  82.448792  96.579121
# ...
